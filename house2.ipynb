# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error,accuracy_score
from sklearn.preprocessing import MinMaxScaler
df=pd.read_csv(r"C:\Users\MathanVini\Downloads\archive (3)\california_housing_test_1.csv")
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                  27         3885             661
# 1       -118.30     34.26                  43         1510             310
# 2       -117.81     33.78                  27         3589             507
# 3       -118.36     33.82                  28           67              15
# 4       -119.67     36.33                  19         1241             244
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                  23         1450             642
# 2996    -118.14     34.06                  27         5257            1082
# 2997    -119.70     36.30                  10          956             201
# 2998    -117.12     34.10                  40           96              14
# 2999    -119.63     34.42                  42         1765             263
#
# ...

# %%
df=df.drop('ocean_proximity',axis=1)
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                  27         3885             661
# 1       -118.30     34.26                  43         1510             310
# 2       -117.81     33.78                  27         3589             507
# 3       -118.36     33.82                  28           67              15
# 4       -119.67     36.33                  19         1241             244
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                  23         1450             642
# 2996    -118.14     34.06                  27         5257            1082
# 2997    -119.70     36.30                  10          956             201
# 2998    -117.12     34.10                  40           96              14
# 2999    -119.63     34.42                  42         1765             263
#
# ...

# %%
df=df.drop('Unnamed: 9',axis=1)
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                  27         3885             661
# 1       -118.30     34.26                  43         1510             310
# 2       -117.81     33.78                  27         3589             507
# 3       -118.36     33.82                  28           67              15
# 4       -119.67     36.33                  19         1241             244
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                  23         1450             642
# 2996    -118.14     34.06                  27         5257            1082
# 2997    -119.70     36.30                  10          956             201
# 2998    -117.12     34.10                  40           96              14
# 2999    -119.63     34.42                  42         1765             263
#
#       population  households  median_income  median_house_value
# ...

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   int64
#  3   total_rooms         3000 non-null   int64
#  4   total_bedrooms      3000 non-null   int64
#  5   population          3000 non-null   int64
#  6   households          3000 non-null   int64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   int64
# dtypes: float64(3), int64(6)
# memory usage: 211.1 KB

# %%
X=df.drop("median_house_value",axis=1)

# %%
df.describe()
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...

# %%
y=df["median_house_value"]
y
# Out:
# 0       344700
# 1       176500
# 2       270500
# 3       330000
# 4        81700
#          ...
# 2995    225000
# 2996    237200
# 2997     62000
# 2998    162500
# 2999    500001
# Name: median_house_value, Length: 3000, dtype: int64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
sc=MinMaxScaler()
sc.fit(X_train)
X_train=sc.transform(X_train)
X_test=sc.transform(X_test)
y_train=sc.fit_transform(y_train.values.reshape(-1,1))
y_test=sc.fit_transform(y_test.values.reshape(-1,1))

# %%
y_test[1]
# Out:
# array([0.12065191])

# %%
a = X_test[1]
a=a.reshape(1,-1)
a
# Out:
# array([[0.53099174, 0.38141026, 0.45098039, 0.07400473, 0.07494923,
#         0.09756915, 0.07974838, 0.0834954 ]])

# %%
model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
m=model.predict(a)
m
# Out:
# array([[0.08742678]])

# %%
y_test = y_test.ravel()  # Converts (600, 1) → (600,)

# %%
m = model.predict(X_test)  # Ensure it outputs (600, 1)
m = m.ravel()  # Convert (600,1) → (600,)

# %%
print("Shape of m before reshaping:", m.shape)
# Out:
# Shape of m before reshaping: (600,)

# %%
print("Shape of y_test:", y_test.shape)
print("Shape of m:", m.shape)
# Out:
# Shape of y_test: (600,)
# Shape of m: (600,)

# %%
m = m.reshape(-1)  # Ensure it's a 1D array
mae = mean_absolute_error(y_test, m)
print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 0.11983086180230129

# %%
#user input given

# %%
input_data = np.array([[-122.05, 37.37, 27, 3885, 661, 1537, 606, 6.6085]])  # Example values

# %%
# Predict house price
predicted_price = model.predict(input_data)
print("Predicted House Price:", predicted_price[0])
# Out:
# Predicted House Price: [-2746.12756727]

# %%
mean_absolute_error(y_test,m)
# Out:
# 0.11983086180230129

# %%
mean_squared_error(y_test,m)
# Out:
# 0.02517689521279241
